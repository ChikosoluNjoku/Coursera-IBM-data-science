# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Njoku Chikosolu Rosemary**
#
# Pharmacist

# %% [markdown]
# _I am interested in data science because i love gaining insights from data, which can be used to make better decisions_

# %% [markdown]
# ### The following code will add two even numbers

# %%
60+40
# Out:
# 100

# %% [markdown]
# **BULLETED LIST**
#
# * Beans
# * Chicken
# * Yam
# * Eggs
#
# **STRIKETHROUGH**
#
# I love learning on coursera. ~~Studying can be tedious, so I quit!!!~~ Winners don't give up, so stay motivated champions!!!
#
# **IMAGE**
#
# Below is an image of a cat downloaded online
# ![Beautiful_Cat_Imge_Download.jpg](attachment:Beautiful_Cat_Imge_Download.jpg)
